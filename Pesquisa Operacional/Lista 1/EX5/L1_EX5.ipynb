# %%
#INSTALAR BIBLIOTECA PULP
# !pip install pulp

from pulp import *

# DEFINIR O MODELO
model = pulp.LpProblem('L1_EX5', sense=LpMaximize)

# ADICIONAR VARIÁVEIS
x = pulp.LpVariable.dicts(indices=[1, 2, 3, 4, 5, 6], cat='LpContinous', lowBound=0, name='x')

# ADICIONAR AS RESTRIÇÕES
model.addConstraint(x[1] + x[2] + x[3] == 800, name='restrição_1')
model.addConstraint(x[1] + x[4] == 400, name='restrição_2')
model.addConstraint(x[2] + x[5] == 700, name='restrição_3')
model.addConstraint(2*x[1] + x[2] + x[6] == 1000, name='restrição_4')

# FUNÇÃO OBJETIVA
model.setObjective(4*x[1] + 3*x[2])

#OTIMIZAR
model.solve()

#OBTER E MOSTRAR RESULTADO
x_sol = {i: x[i].value() for i in [1, 2, 3, 4, 5, 6]}
print(f'x = {x_sol}')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 14.2 MB 5.0 MB/s
# ...
# x = {1: 200.0, 2: 600.0, 3: 0.0, 4: 200.0, 5: 100.0, 6: 0.0}
