# %%
#INSTALAR BIBLIOTECA PULP
# !pip install pulp

from pulp import *

# DEFINIR O MODELO
model = pulp.LpProblem('L2_EX1.1', sense=LpMaximize)

# ADICIONAR VARIÁVEIS
x = pulp.LpVariable.dicts(indices=[1, 2, 3, 4, 5], cat='LpContinous', lowBound=0, name='x')

# ADICIONAR AS RESTRIÇÕES
model.addConstraint(-x[1] + 2*x[2] + x[3] == 4, name='restrição_1')
model.addConstraint(x[1] + 3*x[2] + x[4] == 6, name='restrição_2')
model.addConstraint(x[1] + 2*x[2] + x[5] == 9, name='restrição_3')


# FUNÇÃO OBJETIVA
model.setObjective(30*x[1] + 24*x[2] )

#OTIMIZAR
model.solve()

#OBTER E MOSTRAR RESULTADO
x_sol = {i: x[i].value() for i in [1, 2, 3, 4, 5]}
print(f'x = {x_sol}')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 14.2 MB 5.0 MB/s
# ...
# x = {1: 6.0, 2: 0.0, 3: 10.0, 4: 0.0, 5: 3.0}
